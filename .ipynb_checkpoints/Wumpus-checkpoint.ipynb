# %%
matrix = [[]]

# %%
matrix
# Out:
# [[]]

# %%
import random
from termcolor import cprint, colored

class Board:
    WIDTH = 4
    HEIGHT = 4
    
    def __init__(self):
        self.matrix = [["O" for _ in range(self.HEIGHT)] for _ in range(self.WIDTH)]
        self.valid_coords = self.gen_valid_coords()
        
    def _repr_html_(self):
        color_map = {
            "W": (50,50,50),
            "P": (25,25,25),
            "B": (50,25,25),
            "G": (25,25,50),
            "O": (100,100,100),
            "S": (25,50,25),
            "X": (10,10,10)
        }
        
        html = ""
        for row in self.matrix:
            for ftypes in row:
                r,g,b = (0,0,0)
                for ftype in ftypes:
                    ra, ga, ba = color_map[ftype]
                    color = (r + ra, g + ga, b + ba)
                
                
                html += (
                    f'<span style="'
                    f'color: rgb(255,255,255);'
                    f'background-color: rgb{color};'
                    f'padding:2px;'
                    f'font-family:monospace;'
                    f'width: 30px;'
                    f'height: 30px;'
                    f'display: block;'
                    f'float: left;'
                    f'">'
                    f'{ftypes}'
                    f'</span>'
                )

            html += "<br>"

        return html

    
    def initialize(self):
        wumpus = Feature("W", Feature.CARDINAL, "S", -1000)
        pit1 = Feature("P", Feature.CARDINAL, "B", -1000)
        pit2 = Feature("P", Feature.CARDINAL, "B", -1000)
        pit3 = Feature("P", Feature.CARDINAL, "B", -1000)
        gold = Feature("G", Feature.LOCAL, "X", 1000)
        
        features = [pit1, pit2, pit3, gold, wumpus]
        
        
        for feature in features:
            idx = random.choice(range(len(self.valid_coords)))
            x, y = self.valid_coords[idx]
            
            if self.matrix[x][y] == "O":
                self.matrix[x][y] = ""
                
            self.place_feature(feature, x, y, idx)
            self.change_env(feature, x, y)

    
    def gen_valid_coords(self):
        # Define your bounds
        rows = range(self.WIDTH)
        cols = range(self.HEIGHT)

        # Define excluded coordinates as a set for O(1) lookup
        excluded = {(0, 0), (0, 1), (1, 0)}

        # Generate all possible coordinates excluding the forbidden ones
        return [
            (r, c) 
            for r in rows 
            for c in cols 
            if (r, c) not in excluded
        ]
    
    def place_feature(self, feature, x, y, idx):
        if feature.ftype == "P":
            self.valid_coords.pop(idx) 
    
        self.matrix[x][y] += feature.ftype


        
    def colored_matrix(self):
        pass
            
    
    def change_env(self, feature, x, y):
        for direction in feature.impact:
            dx, dy = direction
            
            if 0 <= x+dx <= 3 and 0 <= y+dy <= 3:
                if self.matrix[x+dx][y+dy] == "O":
                      self.matrix[x+dx][y+dy] = ""
                        
                self.matrix[x+dx][y+dy] += feature.impact_type
            else:
                continue
        

class Feature:
    CARDINAL = [(0,1),(1,0),(-1,0),(0,-1)]
    LOCAL = [(0,0)]
    
    def __init__(self, ftype, impact, impact_type, scoring):
        self.ftype = ftype
        self.impact = impact
        self.impact_type = impact_type
        self.scoring = scoring
        
    def __repr__(self):
        return self.ftype

# %%
board = Board()
board.matrix
board.initialize()
board.matrix

board
# Out:
# <span style="color: rgb(255,255,255);background-color: rgb(100, 100, 100);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">O</span><span style="color: rgb(255,255,255);background-color: rgb(50, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">B</span><span style="color: rgb(255,255,255);background-color: rgb(25, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">P</span><span style="color: rgb(255,255,255);background-color: rgb(50, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">BB</span><br><span style="color: rgb(255,255,255);background-color: rgb(100, 100, 100);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">O</span><span style="color: rgb(255,255,255);background-color: rgb(100, 100, 100);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">O</span><span style="color: rgb(255,255,255);background-color: rgb(50, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">BB</span><span style="color: rgb(255,255,255);background-color: rgb(25, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">P</span><br><span style="color: rgb(255,255,255);background-color: rgb(100, 100, 100);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">O</span><span style="color: rgb(255,255,255);background-color: rgb(50, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">B</span><span style="color: rgb(255,255,255);background-color: rgb(100, 100, 100);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">O</span><span style="color: rgb(255,255,255);background-color: rgb(25, 50, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">BS</span><br><span style="color: rgb(255,255,255);background-color: rgb(10, 10, 10);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">BGX</span><span style="color: rgb(255,255,255);background-color: rgb(25, 25, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">P</span><span style="color: rgb(255,255,255);background-color: rgb(25, 50, 25);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">BS</span><span style="color: rgb(255,255,255);background-color: rgb(50, 50, 50);padding:2px;font-family:monospace;width: 30px;height: 30px;display: block;float: left;">W</span><br>

# %%
board.valid_coords
# Out:
# [(0, 2),
#  (0, 3),
#  (1, 1),
#  (1, 2),
#  (1, 3),
#  (2, 0),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (3, 3)]

# %%
wumpus.__dict__
# Out:
# {'ftype': 'W',
#  'impact': [(0, 1), (1, 0), (-1, 0), (0, -1)],
#  'imapact_type': 'S',
#  'scoring': -1000}

# %%
list(range(1,4))
# Out:
# [1, 2, 3]

# %%
rows = range(4)
cols = range(4)

# Define excluded coordinates as a set for O(1) lookup
excluded = {(0, 0), (0, 1), (1, 0)}

# Generate all possible coordinates excluding the forbidden ones
[
    (r, c) 
    for r in rows 
    for c in cols 
    if (r, c) not in excluded
]
# Out:
# [(0, 2),
#  (0, 3),
#  (1, 1),
#  (1, 2),
#  (1, 3),
#  (2, 0),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (3, 3)]

# %%
pos = "A"

# %%
pos
# Out:
# 'A'

# %%
pos = "B"

# %%
pos
# Out:
# 'B'

# %%
pos += "A"

# %%
pos
# Out:
# 'BA'

# %%
# Out:
# foo
# bar
